# %% [markdown]
# <a href="https://colab.research.google.com/github/Neeraj577/Machine_learning/blob/main/Untitled28.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt


df = pd.read_excel('/content/containerports.xlsx')
df.head(10)
# Out:
#      Container Port  TEUs Processed (1000s)
# 0     Baltimore, MD                     525
# 1        Boston, MA                     165
# 2    Charleston, SC                    1174
# 3       Chester, PA                     125
# 4       Everett, WA                      32
# 5      Freeport, TX                      51
# 6      Gulfport, MS                      86
# 7       Houston, TX                    1996
# 8  Jacksonville, FL                     237
# 9    Long Beach, CA                    4288

# %%
df["TEUs Processed (1000s)"].value_counts()
# Out:
# TEUs Processed (1000s)
# 525     1
# 165     1
# 205     1
# 139     1
# 76      1
# 1316    1
# 1429    1
# 2431    1
# 296     1
# 74      1
# 53      1
# 90      1
# 499     1
# 389     1
# 1102    1
# 1285    1
# 4600    1
# 316     1
# 251     1
# 737     1
# 4999    1
# 4288    1
# 237     1
# 1996    1
# 86      1
# 51      1
# 32      1
# 125     1
# 1174    1
# 131     1
# Name: count, dtype: int64

# %%
raw = [56,	57,	44,	59,	31,49,	52,	52,	26,	65, 55,	48,	21,	27,	41, 72,	24,	45,	41,	31,41,	50,	44,	30,	50,31,	32,	33,	41,	50,40,	61,	40,	36,	35,45,	39,	41,	39,	64
]

# %%
len(raw)
# Out:
# 40
